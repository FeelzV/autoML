# %%
from autogluon.tabular import TabularDataset, TabularPredictor
from autogluon.multimodal import MultiModalPredictor
import pandas as pd
from utils import load

# %%
blobs_data_train, blobs_data_test = load('blobs')
blobs_predictor = TabularPredictor(label='label').fit(blobs_data_train)
# Out:
# No path specified. Models will be saved in: "AutogluonModels\ag-20230322_192909\"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels\ag-20230322_192909\"
# AutoGluon Version:  0.7.0
# Python Version:     3.10.9
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.19044
# Train Data Rows:    4000
# Train Data Columns: 2
# Label Column: label
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'multiclass' (because dtype of label-column == int, but few unique label-values observed).
# 	5 unique label values:  [3, 1, 2, 4, 0]
# 	If 'multiclass' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Train Data Class Count: 5
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    13886.47 MB
# 	Train Data (Original)  Memory Usage: 0.06 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 2 | ['x', 'y']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 2 | ['x', 'y']
# 	0.0s = Fit runtime
# 	2 features in original data used to generate 2 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.06 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.05s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.125, Train Rows: 3500, Val Rows: 500
# Fitting 13 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	0.992	 = Validation score   (accuracy)
# 	0.01s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	0.988	 = Validation score   (accuracy)
# 	0.01s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# No improvement since epoch 4: early stopping
# 	0.992	 = Validation score   (accuracy)
# 	3.23s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMXT ...
# 	0.986	 = Validation score   (accuracy)
# 	0.89s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM ...
# 	0.99	 = Validation score   (accuracy)
# 	1.0s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForestGini ...
# 	0.992	 = Validation score   (accuracy)
# 	0.64s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: RandomForestEntr ...
# 	0.992	 = Validation score   (accuracy)
# 	0.62s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: CatBoost ...
# 	0.992	 = Validation score   (accuracy)
# 	1.62s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTreesGini ...
# 	0.99	 = Validation score   (accuracy)
# 	0.6s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: ExtraTreesEntr ...
# 	0.99	 = Validation score   (accuracy)
# 	0.6s	 = Training   runtime
# 	0.08s	 = Validation runtime
# Fitting model: XGBoost ...
# 	0.992	 = Validation score   (accuracy)
# 	0.69s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch ...
# 	0.992	 = Validation score   (accuracy)
# 	4.06s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# 	0.988	 = Validation score   (accuracy)
# 	2.37s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	0.992	 = Validation score   (accuracy)
# 	0.54s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 17.63s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels\ag-20230322_192909\")

# %%
predictions = blobs_predictor.evaluate(blobs_data_test)
# Out:
# Evaluation: accuracy on test data: 0.99
# Evaluations on test data:
# {
#     "accuracy": 0.99,
#     "balanced_accuracy": 0.9899736013808509,
#     "mcc": 0.9875327539813711
# }

# %%
circles_data_train, circles_data_test = load('circles')
circles_predictor = TabularPredictor(label='label').fit(circles_data_train)
# Out:
# No path specified. Models will be saved in: "AutogluonModels\ag-20230322_192927\"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels\ag-20230322_192927\"
# AutoGluon Version:  0.7.0
# Python Version:     3.10.9
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.19044
# Train Data Rows:    4000
# Train Data Columns: 2
# Label Column: label
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  [1, 0]
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    13888.13 MB
# 	Train Data (Original)  Memory Usage: 0.06 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 2 | ['x', 'y']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 2 | ['x', 'y']
# 	0.0s = Fit runtime
# 	2 features in original data used to generate 2 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.06 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.05s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.125, Train Rows: 3500, Val Rows: 500
# Fitting 13 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	0.886	 = Validation score   (accuracy)
# 	0.01s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	0.884	 = Validation score   (accuracy)
# 	0.01s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMXT ...
# 	0.888	 = Validation score   (accuracy)
# 	0.86s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBM ...
# 	0.882	 = Validation score   (accuracy)
# 	0.57s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForestGini ...
# 	0.866	 = Validation score   (accuracy)
# 	0.6s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: RandomForestEntr ...
# 	0.87	 = Validation score   (accuracy)
# 	0.57s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: CatBoost ...
# 	0.892	 = Validation score   (accuracy)
# 	1.03s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTreesGini ...
# 	0.878	 = Validation score   (accuracy)
# 	0.54s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: ExtraTreesEntr ...
# 	0.88	 = Validation score   (accuracy)
# 	0.54s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# 	0.904	 = Validation score   (accuracy)
# 	3.85s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: XGBoost ...
# 	0.904	 = Validation score   (accuracy)
# 	0.42s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch ...
# 	0.898	 = Validation score   (accuracy)
# 	5.5s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# 	0.886	 = Validation score   (accuracy)
# 	0.87s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	0.904	 = Validation score   (accuracy)
# 	0.69s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 16.71s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels\ag-20230322_192927\")

# %%
predictions = circles_predictor.evaluate(circles_data_test)
# Out:
# Evaluation: accuracy on test data: 0.914
# Evaluations on test data:
# {
#     "accuracy": 0.914,
#     "balanced_accuracy": 0.9143209599641136,
#     "mcc": 0.8281644158609567,
#     "roc_auc": 0.9720998413944473,
#     "f1": 0.9118852459016394,
#     "precision": 0.9008097165991903,
#     "recall": 0.9232365145228216
# }

# %%
moons_data_train, moons_data_test = load('moons')
moons_predictor = TabularPredictor(label='label').fit(moons_data_train)
# Out:
# No path specified. Models will be saved in: "AutogluonModels\ag-20230322_192943\"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels\ag-20230322_192943\"
# AutoGluon Version:  0.7.0
# Python Version:     3.10.9
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.19044
# Train Data Rows:    4000
# Train Data Columns: 2
# Label Column: label
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  [0, 1]
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    13890.75 MB
# 	Train Data (Original)  Memory Usage: 0.06 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 2 | ['x', 'y']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 2 | ['x', 'y']
# 	0.0s = Fit runtime
# 	2 features in original data used to generate 2 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.06 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.04s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.125, Train Rows: 3500, Val Rows: 500
# Fitting 13 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	0.986	 = Validation score   (accuracy)
# 	0.01s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	0.988	 = Validation score   (accuracy)
# 	0.01s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMXT ...
# 	0.994	 = Validation score   (accuracy)
# 	0.62s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBM ...
# 	0.99	 = Validation score   (accuracy)
# 	0.5s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForestGini ...
# 	0.994	 = Validation score   (accuracy)
# 	0.56s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: RandomForestEntr ...
# 	0.992	 = Validation score   (accuracy)
# 	0.53s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: CatBoost ...
# 	0.992	 = Validation score   (accuracy)
# 	0.79s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTreesGini ...
# 	0.992	 = Validation score   (accuracy)
# 	0.52s	 = Training   runtime
# 	0.06s	 = Validation runtime
# Fitting model: ExtraTreesEntr ...
# 	0.99	 = Validation score   (accuracy)
# 	0.52s	 = Training   runtime
# 	0.07s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# 	0.996	 = Validation score   (accuracy)
# 	3.85s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: XGBoost ...
# 	0.99	 = Validation score   (accuracy)
# 	0.35s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch ...
# 	0.998	 = Validation score   (accuracy)
# 	4.56s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# 	0.99	 = Validation score   (accuracy)
# 	1.15s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	0.998	 = Validation score   (accuracy)
# 	0.69s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 15.25s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels\ag-20230322_192943\")

# %%
predictions = moons_predictor.evaluate(moons_data_test)
# Out:
# Evaluation: accuracy on test data: 0.991
# Evaluations on test data:
# {
#     "accuracy": 0.991,
#     "balanced_accuracy": 0.9910199294723232,
#     "mcc": 0.9819907274236245,
#     "roc_auc": 0.9997198105919601,
#     "f1": 0.9912195121951219,
#     "precision": 0.9921875,
#     "recall": 0.9902534113060428
# }

# %%
regression_data_train, regression_data_test = load('regression')
regression_predictor = TabularPredictor(label='y').fit(regression_data_train)
# Out:
# No path specified. Models will be saved in: "AutogluonModels\ag-20230322_192959\"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels\ag-20230322_192959\"
# AutoGluon Version:  0.7.0
# Python Version:     3.10.9
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.19044
# Train Data Rows:    4000
# Train Data Columns: 1
# Label Column: y
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (257.9671624962504, -252.54116078027369, 0.50394, 72.12249)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    13888.2 MB
# 	Train Data (Original)  Memory Usage: 0.03 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 1 | ['x']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 1 | ['x']
# 	0.0s = Fit runtime
# 	1 features in original data used to generate 1 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.03 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.04s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.125, Train Rows: 3500, Val Rows: 500
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	-15.7354	 = Validation score   (-root_mean_squared_error)
# 	0.0s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	-17.5856	 = Validation score   (-root_mean_squared_error)
# 	0.01s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMXT ...
# [1000]	valid_set's rmse: 14.894
# [2000]	valid_set's rmse: 14.8546
# [3000]	valid_set's rmse: 14.8494
# 	-14.8446	 = Validation score   (-root_mean_squared_error)
# 	2.26s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM ...
# 	-14.9419	 = Validation score   (-root_mean_squared_error)
# 	0.56s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: RandomForestMSE ...
# 	-18.0342	 = Validation score   (-root_mean_squared_error)
# 	0.47s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: CatBoost ...
# 	-14.7631	 = Validation score   (-root_mean_squared_error)
# 	0.72s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTreesMSE ...
# 	-17.0985	 = Validation score   (-root_mean_squared_error)
# 	0.44s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# 	-14.7282	 = Validation score   (-root_mean_squared_error)
# 	3.69s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: XGBoost ...
# 	-14.8435	 = Validation score   (-root_mean_squared_error)
# 	0.39s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch ...
# 	-14.837	 = Validation score   (-root_mean_squared_error)
# 	4.57s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# 	-15.097	 = Validation score   (-root_mean_squared_error)
# 	1.23s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	-14.6892	 = Validation score   (-root_mean_squared_error)
# 	0.26s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 15.23s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels\ag-20230322_192959\")

# %%
predictions = regression_predictor.evaluate(regression_data_test)
# Out:
# c:\Users\marin\miniconda3\envs\automl\lib\site-packages\autogluon\tabular\predictor\predictor.py:1420: FutureWarning: Calling `predictor.predict_proba` when problem_type=regression will raise an AssertionError starting in AutoGluon v0.8. Please call `predictor.predict` instead.
#   warnings.warn(
# Evaluation: root_mean_squared_error on test data: -15.439238660175869
# 	Note: Scores are always higher_is_better. This metric score can be multiplied by -1 to get the metric value.
# Evaluations on test data:
# {
#     "root_mean_squared_error": -15.439238660175869,
#     "mean_squared_error": -238.37009040586918,
#     "mean_absolute_error": -12.427862501664308,
#     "r2": 0.9559533168047499,
#     "pearsonr": 0.9777768708683935,
#     "median_absolute_error": -10.760704774203425
# }

# %%
titanic_data_train, titanic_data_test = load('titanic')
titanic_predictor = TabularPredictor(label='survived').fit(titanic_data_train)
# Out:
# No path specified. Models will be saved in: "AutogluonModels\ag-20230322_195551\"
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels\ag-20230322_195551\"
# AutoGluon Version:  0.7.0
# Python Version:     3.10.9
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.19044
# Train Data Rows:    1047
# Train Data Columns: 11
# Label Column: survived
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'binary' (because only two unique label-values observed).
# 	2 unique label values:  [0, 1]
# 	If 'binary' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Selected class <--> label mapping:  class 1 = 1, class 0 = 0
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    5719.9 MB
# 	Train Data (Original)  Memory Usage: 0.42 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 1 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 		Fitting TextSpecialFeatureGenerator...
# 			Fitting BinnedFeatureGenerator...
# 			Fitting DropDuplicatesFeatureGenerator...
# Epoch 0:   1%|          | 22/1980 [30:11<44:47:42, 82.36s/it, loss=1.82, v_num=]
# 		Fitting TextNgramFeatureGenerator...
# 			Fitting CountVectorizer for text features: ['name', 'home.dest']
# 			CountVectorizer fit with vocabulary size = 18
# 		Warning: Due to memory constraints, ngram feature count is being reduced. Allocate more memory to maximize model quality.
# 		Reducing Vectorizer vocab size from 18 to 9 to avoid OOM error
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])        : 2 | ['age', 'fare']
# 		('int', [])          : 3 | ['pclass', 'sibsp', 'parch']
# 		('object', [])       : 4 | ['sex', 'ticket', 'cabin', 'embarked']
# 		('object', ['text']) : 2 | ['name', 'home.dest']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])                    :  3 | ['ticket', 'cabin', 'embarked']
# 		('category', ['text_as_category'])  :  1 | ['home.dest']
# 		('float', [])                       :  2 | ['age', 'fare']
# 		('int', [])                         :  3 | ['pclass', 'sibsp', 'parch']
# 		('int', ['binned', 'text_special']) : 17 | ['name.char_count', 'name.word_count', 'name.capital_ratio', 'name.lower_ratio', 'name.special_ratio', ...]
# 		('int', ['bool'])                   :  1 | ['sex']
# 		('int', ['text_ngram'])             : 10 | ['__nlp__.miss', '__nlp__.mr', '__nlp__.mrs', '__nlp__.new', '__nlp__.new york', ...]
# 	20.9s = Fit runtime
# 	11 features in original data used to generate 37 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.09 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 20.91s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'accuracy'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 837, Val Rows: 210
# Fitting 13 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	0.6524	 = Validation score   (accuracy)
# 	0.01s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	0.6238	 = Validation score   (accuracy)
# 	0.01s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMXT ...
# 	0.8429	 = Validation score   (accuracy)
# 	0.68s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBM ...
# 	0.8476	 = Validation score   (accuracy)
# 	0.64s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: RandomForestGini ...
# 	0.7905	 = Validation score   (accuracy)
# 	0.55s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: RandomForestEntr ...
# 	0.7905	 = Validation score   (accuracy)
# 	0.51s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: CatBoost ...
# 	0.8476	 = Validation score   (accuracy)
# 	9.92s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: ExtraTreesGini ...
# 	0.7952	 = Validation score   (accuracy)
# 	0.52s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: ExtraTreesEntr ...
# 	0.8048	 = Validation score   (accuracy)
# 	0.5s	 = Training   runtime
# 	0.05s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# No improvement since epoch 6: early stopping
# 	0.8286	 = Validation score   (accuracy)
# 	1.13s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: XGBoost ...
# 	0.8381	 = Validation score   (accuracy)
# 	0.66s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: NeuralNetTorch ...
# 	0.8238	 = Validation score   (accuracy)
# 	3.05s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# 	0.8048	 = Validation score   (accuracy)
# 	1.0s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ...
# 	0.8571	 = Validation score   (accuracy)
# 	0.6s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 41.25s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels\ag-20230322_195551\")

# %%
predictions = titanic_predictor.evaluate(titanic_data_test)
# Out:
# Evaluation: accuracy on test data: 0.851145038167939
# Evaluations on test data:
# {
#     "accuracy": 0.851145038167939,
#     "balanced_accuracy": 0.818395061728395,
#     "mcc": 0.6843880081575228,
#     "roc_auc": 0.8457407407407407,
#     "f1": 0.7771428571428572,
#     "precision": 0.9066666666666666,
#     "recall": 0.68
# }

# %%
emotion_data_train, emotion_data_test = load('emotion')
emotion_predictor = MultiModalPredictor(label='label').fit(emotion_data_train)
predictions = emotion_predictor.evaluate(emotion_data_test)
# Out:
# Global seed set to 123
# No path specified. Models will be saved in: "AutogluonModels\ag-20230322_193531\"
# AutoMM starts to create your model. ✨
#
# - Model will be saved to "c:\Explorai\autoML\AutogluonModels\ag-20230322_193531".
#
# - Validation metric is "accuracy".
#
# - To track the learning progress, you can open a terminal and launch Tensorboard:
#     ```shell
#     # Assume you have installed tensorboard
#     tensorboard --logdir c:\Explorai\autoML\AutogluonModels\ag-20230322_193531
#     ```
#
# Enjoy your coffee, and let AutoMM do the job ☕☕☕ Learn more at https://auto.gluon.ai
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:3                                                                                    │
# │                                                                                                  │
# │   1 from autogluon.text import TextPredictor                                                     │
# │   2 emotion_data_train, emotion_data_test = load('emotion')                                      │
# │ ❱ 3 emotion_predictor = TextPredictor(label='label').fit(emotion_data_train)                     │
# │   4 predictions = emotion_predictor.evaluate(emotion_data_test)                                  │
# │   5                                                                                              │
# │                                                                                                  │
# │ c:\Users\marin\miniconda3\envs\automl\lib\site-packages\autogluon\text\text_prediction\predictor │
# │ .py:257 in fit                                                                                   │
# │                                                                                                  │
# │   254 │   │   │   if isinstance(teacher_predictor, TextPredictor):                               │
# │   255 │   │   │   │   teacher_predictor = teacher_predictor._predictor                           │
# │   256 │   │   │                                                                                  │
# │ ❱ 257 │   │   │   self._predictor.fit(                                                           │
# │   258 │   │   │   │   train_data=train_data,                                                     │
# │   259 │   │   │   │   tuning_data=tuning_data,                                                   │
# │   260 │   │   │   │   time_limit=time_limit,                                                     │
# │                                                                                                  │
# │ c:\Users\marin\miniconda3\envs\automl\lib\site-packages\autogluon\multimodal\predictor.py:825 in │
# │ fit                                                                                              │
# │                                                                                                  │
# │    822 │   │   │   config=config,                                                                │
# │    823 │   │   │   hyperparameters=hyperparameters,                                              │
# │    824 │   │   │   teacher_predictor=teacher_predictor,                                          │
# │ ❱  825 │   │   │   standalone=standalone,                                                        │
# │    826 │   │   │   hpo_mode=(hyperparameter_tune_kwargs is not None),  # skip average checkpoin  │
# │    827 │   │   │   clean_ckpts=clean_ckpts,                                                      │
# │    828 │   │   )                                                                                 │
# │                                                                                                  │
# │ c:\Users\marin\miniconda3\envs\automl\lib\site-packages\autogluon\multimodal\predictor.py:990 in │
# │ _fit                                                                                             │
# │                                                                                                  │
# │    987 │   │   val_df: pd.DataFrame,                                                             │
# │    988 │   │   validation_metric_name: str,                                                      │
# │    989 │   │   minmax_mode: str,                                                                 │
# │ ❱  990 │   │   max_time: timedelta,                                                              │
# │    991 │   │   save_path: str,                                                                   │
# │    992 │   │   ckpt_path: str,                                                                   │
# │    993 │   │   resume: bool,                                                                     │
# │                                                                                                  │
# │ c:\Users\marin\miniconda3\envs\automl\lib\site-packages\autogluon\multimodal\utils\config.py:194 │
# │ in get_config                                                                                    │
# │                                                                                                  │
# │   191                                                                                            │
# │   192                                                                                            │
# │   193 def verify_model_names(config: DictConfig):                                                │
# │ ❱ 194 │   """                                                                                    │
# │   195 │   Verify whether provided model names are valid.                                         │
# │   196 │                                                                                          │
# │   197 │   Parameters                                                                             │
# │                                                                                                  │
# │ c:\Users\marin\miniconda3\envs\automl\lib\site-packages\autogluon\multimodal\utils\config.py:502 │
# │ in apply_omegaconf_overrides                                                                     │
# │                                                                                                  │
# │   499 │   num_numerical_columns: Optional[int] = 0,                                              │
# │   500 │   num_categorical_columns: Optional[int] = 0,                                            │
# │   501 │   resource: Optional[int] = 16,                                                          │
# │ ❱ 502 ):                                                                                         │
# │   503 │   """                                                                                    │
# │   504 │   Modify configs based on the dataset statistics.                                        │
# │   505 │   Use Additive attention with large column count and tune batch size accordingly.        │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# KeyError: '"model.document_transformer.checkpoint_name" is not found in the config. You may need to check the
# overrides. overrides={\'model.names\': [\'categorical_mlp\', \'numerical_mlp\', \'timm_image\', \'hf_text\',
# \'document_transformer\', \'fusion_mlp\'], \'model.hf_text.checkpoint_name\':
# \'google/electra-base-discriminator\', \'model.timm_image.checkpoint_name\': \'swin_base_patch4_window7_224\',
# \'model.document_transformer.checkpoint_name\': \'microsoft/layoutlmv3-base\'}'
